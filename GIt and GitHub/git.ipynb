# %% [markdown]
# Git - Version Control Software
#
# VC -
#
# Repo - Store Codes
#
# -> create repo in github
#
# then we want to connect github and folder
#
# -> select the folder we want
# then > git clone https::// (this is git repository link)
#
# if first time we do gitHub config ..
# > git config --global user.name [username in gitHub]
# > git config --global user.email [user email in gitHub]
#
# after doing clone we see
# ->we see .git Folder => this is the connection between your local repo and your cloud repo
# 			this folder do create a communication , creating hash for doing commits , etc
# [don't delete this folder]
#
#
# open VScode
# -> Open Sample Project (any Project)
# create Dummy.text file nd give this some dummy text data(for education Purpose)
# then there is U -> symbol in that folder -> this means Untracked
#
# before we see about Untracked.. we are going to see staging and Unstaging
#
# we have "git add" command in github  -> * ithu enna pannum naa.. namma files laam stage panna ready aaaki vaikum
#                                         * then commit panna , antha files laam stage aagum
# 					* then push panna, stage aana files ellam cloud ku poidum
#
# example for stage(add), commit , push
#
# -ippo yaarukavathu oru letter yeluthurom naa, yeluthura files lam oru envelope la poduvom la athu than git add
# -then antha letter ah seal pannitu mela from and To address and Date , nd name laam yeluthuvom la athu athan commit
# -then itha yarkittayvathu kuduthu post panrom la athu thaan pushing
# -then 'commit hash' apdinu oru concept iruku..(namma envelope la name , from and to address date ellam kalanthu , unique aana oru num genereate aagum antha number peru than commit hash )
#
# 1) first itha stage pannanum nu nenacha
# > git add Sample(file name)  -[ippo namma staging ku ready panniyachu]
#
# 2) then atha commit pannanum
# > git commit -m "feat: added my name"
#
# 3)then push panrom
# > git push    [Stage panna file mattum than pogum, (add and commit panna files)]
#
# ellam mudinchu , ipppo ithula yetho thappu iruku , previous version ke poganum apdina ..
# > git reset
#
#
# then yethavathu pannirukanga other , developers or github la direct aah edit pannirukanga, anga iruka changes ah epdi inga kondu varathu
# > git pull
#
#
#
# Then we are going to see >git status
# ipo rendu file local la create panrom nu vachupom
# 1) index.html
# 2) base.html
# 	enaku ithula index.html mattum than commit and push pannaum , base.html ah panna vendam nu nenacha..
#       > git add .\index.html
#       > git commit -m "feat:created a html file"
#
# then naan push panla maranthuten .. enna pannanum nu so atha epdi track panrathunaa..
#   > git status
#   (ithula ennalam stage aagi ready iruku / ila  ndrathu vanthurum
# then namaku venum naa >git push kuduthukalam ..
#
# then >git diff naa ennanu pathuralam
# 	index.html la yethavthu oru change pannuvom code la..
# then >git diff kuduthom naa.. enna differnce nu kaatum , already commmit pannathukum ipo commit pannama iruka code kum
# ithu 'M' (Modified) nu kaatum
#
# then itha add, commit and push panniduvom
# > git add . (intha dot use panna current folder la iruka ella files um staging ku ready aagirum)
# > git commit
# > git push
# (it's a good we do git pull before git push)
# ipdi than Local and Global repo va Sync pannanum..
#
#
# Now team kooda epdi work panrathunu papom
# ---Working with other Developers---
# ipo rendu peru oru project la work panranga nu vachupom..
# oruthar frontend , another one backend rendu perum seperate work pannanum.. becoz nan panra thappu avana affect panna kooodathu , avan panra thappu ennna baathika kooodathu..
# naan panra thappunaala enna changes nadakum nu enaku therium, avan panra thappu naala enna changes nadakum nu avanuku therium..
# ipo rendu perum orey yedathula pull and push panna .. ennoda thappaana code um avanuku irukum , avnoda thappaana code enakuu irukum..
# rendu perukum code work aagathu.. rendu perukum enna thappu pannom nu rendu perukum theriyathu
# itha avoid panna thann 'branching' apdindra concept vanthuchu
# 1) Naan backend ndra branch create pannni work pannuven
# 2) En friend frontend ndra branch create panni work pannuvaan
#
# last la rendu branch um merge pannathuku aprom rendumey work aaga start aagirum
# antha time la naanga main branch branch la irunthu innoru clone yeduthu work panna start panniduvom
#
# itha epdi simulate panrathunu pakalam
# >git branch (yentha branch la current ah irukom apdindratha show pannum.. )
#
# ipo puthusa oru branch create pannanum apdina..
# >git checkout -b "backend"(branch name)
#
# then entha branch la irukom nu check panrthuku
# >git branch
#
# Now enaku again main branch ku poganum apdinaa..
# >git checkout main (Now itha chack pannanum apdina >git branch kuduthu check pannikalam)
#
# OK.. ipo namma again backend branch key poidalam
# >git checkout -b 'backend'
# (ithula iruka code la yethavathu oru chinna changes pannikalam)
#
# now try to commit and push this branch
# >git add.
# >git commit -m "feet:added some backend"
# >git push
#
# Now upstream set panla apdinu solluthu..
#
# APP_TYPE=100
# APP_CODE=100
# BRAND="AARAN"
